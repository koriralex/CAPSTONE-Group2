# %% [markdown]
# <a href="https://colab.research.google.com/github/koriralex/CAPSTONE-Group2/blob/main/3D_script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
import pandas as pd
from datetime import datetime, timedelta

# Convert UTC time to Nairobi time and format as MM/DD/YYYY
def convert_to_nairobi_date(utc_time_str):
    try:
        utc_time = datetime.strptime(utc_time_str, "%d.%m.%Y %H:%M:%S")
        nairobi_time = utc_time + timedelta(hours=3)
        return nairobi_time.strftime("%m/%d/%Y")  # MM/DD/YYYY format
    except ValueError as e:
        print(f"Error converting time: {e}")
        return None

# Convert time string to timedelta, handling errors
def convert_to_timedelta(time_str):
    try:
        if not isinstance(time_str, str) or ":" not in time_str:
            return pd.Timedelta(0)  # Return zero if time format is invalid
        return pd.to_timedelta(time_str)
    except Exception as e:
        print(f"Error converting '{time_str}' to Timedelta: {e}")
        return pd.Timedelta(0)

# Step 1: Log in to get session ID
login_url = "https://hst-api.wialon.com/wialon/ajax.html"
login_params = {
    "svc": "token/login",
    "params": json.dumps({"token": "2fafffda4015e09fe3af4feba6a3529cB20738374781590B0467AD494992D450FFBB4E12"})
}

login_response = requests.get(login_url, params=login_params)
login_data = login_response.json()
sid = login_data.get('eid')

if not sid:
    print("Failed to retrieve session ID:", login_data)
else:
    print("Session ID:", sid)

    # Step 2: Execute report
    report_url = "https://hst-api.wialon.com/wialon/ajax.html"
    report_params = {
        "svc": "report/exec_report",
        "params": json.dumps({
            "reportResourceId": 17649024,
            "reportTemplateId": 69,
            "reportObjectId": 16471919,
            "reportObjectSecId": 0,
            "interval": {
                "from": 1740819600,  # Unix timestamp for 04/09/2024
                "to":  1743411600,    # Unix timestamp for 04/09/2024
                "flags": 0
            },
            "tzOffset": 0,
            "lang": "en"
        }),
        "sid": sid
    }

    report_response = requests.get(report_url, params=report_params)
    report_data = report_response.json()

    if 'error' in report_data:
        print("Failed to retrieve report:", report_data)
    else:
        print("Report data successfully retrieved")

        # Step 3: Retrieve header rows only (not aggregated)
        rows_url = "https://hst-api.wialon.com/wialon/ajax.html"
        trip_data = []
        index_from = 0
        chunk_size = 100  # Fetch rows in batches

        while True:
            rows_params = {
                "svc": "report/get_result_rows",
                "params": json.dumps({
                    "tableIndex": 0,
                    "indexFrom": index_from,
                    "indexTo": index_from + chunk_size - 1
                }),
                "sid": sid
            }

            rows_response = requests.get(rows_url, params=rows_params)
            rows_data = rows_response.json()

            if 'error' in rows_data:
                print("Failed to retrieve rows:", rows_data)
                break

            if isinstance(rows_data, dict) and 'rows' in rows_data:
                current_chunk = rows_data['rows']
            else:
                current_chunk = rows_data

            for row in current_chunk:
                try:
                    row_data = row["c"]
                    trip = {
                        "Truck No": row_data[0].replace(" ", "")[:7],  # Remove spaces, take first 7 chars
                        "Date": convert_to_nairobi_date(row_data[1]["t"]),  # MM/DD/YYYY format
                        "Driving Time": convert_to_timedelta(row_data[4]) if len(row_data) > 4 else pd.Timedelta(0),
                        "Standing Time": convert_to_timedelta(row_data[5]) if len(row_data) > 5 else pd.Timedelta(0),
                        "Idle Time": convert_to_timedelta(row_data[6]) if len(row_data) > 6 else pd.Timedelta(0),
                        "Distance (km)": float(row_data[8].replace("km", "").strip()) if len(row_data) > 8 else 0.0
                    }
                    trip_data.append(trip)
                except (IndexError, KeyError, TypeError, ValueError) as e:
                    print(f"Error processing row {row}: {e}")

            if len(current_chunk) < chunk_size:
                break  # No more data to fetch

            index_from += chunk_size  # Move to next batch

        # Step 4: Convert to DataFrame
        df = pd.DataFrame(trip_data)

        # Convert Date to datetime format
        df["Date"] = pd.to_datetime(df["Date"], format="%m/%d/%Y")

        # Extract Year-Month for grouping
        df["Month"] = df["Date"].dt.strftime("%Y-%m")

        # Step 5: Aggregate per Truck per Month per Day
        df_grouped = df.groupby(["Truck No", "Month", "Date"]).agg({
            "Driving Time": "sum",
            "Standing Time": "sum",
            "Idle Time": "sum",
            "Distance (km)": "sum"
        }).reset_index()

        # Convert time columns back to string format for easy readability
        df_grouped["Driving Time"] = df_grouped["Driving Time"].astype(str)
        df_grouped["Standing Time"] = df_grouped["Standing Time"].astype(str)
        df_grouped["Idle Time"] = df_grouped["Idle Time"].astype(str)

        # Step 6: Sort the data by Truck No and Date
        df_grouped = df_grouped.sort_values(by=["Truck No", "Month", "Date"])

        # Step 7: Save to Excel
        output_file = "Trip_History_Per_Truck_Per_Month.xlsx"
        df_grouped.to_excel(output_file, index=False, sheet_name="Trip History")

        print(f"Trip history data successfully exported as {output_file}")

        # Step 8: Download the file in Colab
        from google.colab import files
        files.download(output_file)
# Out:
# Session ID: 092423fe5bd16df176c9f28a16047b72
# Report data successfully retrieved
# Trip history data successfully exported as Trip_History_Per_Truck_Per_Month.xlsx

# %%
import requests
import json
import pandas as pd
from datetime import datetime, timedelta
from google.colab import files

# Function to convert UTC time to Nairobi time and format to MM/DD/YYYY HH:MM:SS
def convert_to_nairobi_time(utc_time_str):
    try:
        utc_time = datetime.strptime(utc_time_str, "%d.%m.%Y %H:%M:%S")
        nairobi_time = utc_time + timedelta(hours=3)
        return nairobi_time.strftime("%m/%d/%Y %H:%M:%S")
    except ValueError as e:
        print(f"Error converting time: {e}")
        return utc_time_str

# Function to convert driving/standing time to timedelta
def convert_to_timedelta(time_str):
    try:
        return pd.to_timedelta(time_str)
    except ValueError as e:
        print(f"Error converting to Timedelta: {e}")
        return time_str

# Function to fetch sub-rows for a specific row
def fetch_subrows(sid, table_index, row_index):
    subrows_url = "https://hst-api.wialon.com/wialon/ajax.html"
    subrows_params = {
        "svc": "report/get_result_subrows",
        "params": json.dumps({"tableIndex": table_index, "rowIndex": row_index}),
        "sid": sid
    }

    # Send request
    subrows_response = requests.get(subrows_url, params=subrows_params)
    subrows_data = subrows_response.json()

    # Check and return sub-rows
    if isinstance(subrows_data, dict) and 'rows' in subrows_data:
        return subrows_data['rows']
    elif isinstance(subrows_data, list):
        return subrows_data
    else:
        print(f"Failed to retrieve sub-rows for row {row_index}: {subrows_data}")
        return []

# Step 1: Log in and get session ID
login_url = "https://hst-api.wialon.com/wialon/ajax.html"
login_params = {
    "svc": "token/login",
    "params": json.dumps({
        "token": "2fafffda4015e09fe3af4feba6a3529cB20738374781590B0467AD494992D450FFBB4E12"
    })
}

login_response = requests.get(login_url, params=login_params)
login_data = login_response.json()
sid = login_data.get('eid')

if not sid:
    print("Failed to retrieve session ID:", login_data)
else:
    print("Session ID:", sid)

    # Step 2: Execute Report
    report_url = "https://hst-api.wialon.com/wialon/ajax.html"
    report_params = {
        "svc": "report/exec_report",
        "params": json.dumps({
            "reportResourceId": 17649024,
            "reportTemplateId": 69,
            "reportObjectId": 16471919,
            "reportObjectSecId": 0,
            "interval": {
                "from": 1740819600,  # Unix timestamp for start date
                "to":  1743411600,    # Unix timestamp for end date
                "flags": 0
            },
            "tzOffset": 0,
            "lang": "en"
        }),
        "sid": sid
    }

    report_response = requests.get(report_url, params=report_params)
    report_data = report_response.json()

    if 'error' in report_data:
        print("Failed to retrieve report:", report_data)
    else:
        print("Report data successfully retrieved")

        # Step 3: Fetch all rows with pagination
        rows_url = "https://hst-api.wialon.com/wialon/ajax.html"
        sub_rows_data = []
        index_from = 0
        chunk_size = 100  # Number of rows per request

        while True:
            rows_params = {
                "svc": "report/get_result_rows",
                "params": json.dumps({
                    "tableIndex": 0,
                    "indexFrom": index_from,
                    "indexTo": index_from + chunk_size - 1
                }),
                "sid": sid
            }

            rows_response = requests.get(rows_url, params=rows_params)
            rows_data = rows_response.json()

            if 'error' in rows_data:
                print("Failed to retrieve rows:", rows_data)
                break

            if isinstance(rows_data, dict) and 'rows' in rows_data:
                current_chunk = rows_data['rows']
            else:
                current_chunk = rows_data

            # Fetch sub-rows for each row
            for idx, row in enumerate(current_chunk):
                sub_rows = fetch_subrows(sid, table_index=0, row_index=index_from + idx)
                if sub_rows:
                    sub_rows_data.extend(sub_rows)

            # Check if this was the last batch
            if len(current_chunk) < chunk_size:
                break

            index_from += chunk_size

        # Step 4: Convert sub-rows to DataFrame
        formatted_sub_rows = []
        for sub_item in sub_rows_data:
            try:
                sub_data = sub_item["c"]
                sub_row = {
                    "Truck No": sub_data[0].replace(" ", "")[:7],  # Remove spaces and pick first 7 characters
                    "Departure DateTime": convert_to_nairobi_time(sub_data[1]["t"]),
                    "Departure From": sub_data[2]["t"],
                    "Arrival DateTime": convert_to_nairobi_time(sub_data[3]["t"]),
                    "Driving Time": convert_to_timedelta(sub_data[4]),
                    "Standing Time": convert_to_timedelta(sub_data[5]),
                    "Idle Time": (convert_to_timedelta(sub_data[5]).days * 24) +
                                (convert_to_timedelta(sub_data[5]).seconds // 3600) +
                                (convert_to_timedelta(sub_data[5]).seconds % 3600) / 3600,
                    "Arrived at": sub_data[6]["t"],
                    "Distance": float(sub_data[8].replace("km", "").strip()),
                    "Maximum Speed": sub_data[9]["t"],
                    "Average Speed": sub_data[10],
                    "Driver": sub_data[11]
                }
                formatted_sub_rows.append(sub_row)
            except (IndexError, KeyError, TypeError) as e:
                print(f"Error processing sub-item {sub_item}: {e}")

        # Convert to DataFrame
        Trip_history_subrows = pd.DataFrame(formatted_sub_rows)

        # Step 5: Export to Excel in Google Colab and Download
        output_file = "/content/Trip_history_subrows.xlsx"
        Trip_history_subrows.to_excel(output_file, index=False, sheet_name="Trip history subrows")

        # Provide a download link
        files.download(output_file)

        print("Sub-rows data successfully exported and ready for download!")

# Display the DataFrame
Trip_history_subrows
# Out:
# Session ID: 09a258ae0aafd2b6b881e3e517ceb3a3
# Report data successfully retrieved
# Error processing sub-item {'n': 130, 'i1': 33267, 'i2': 33333, 't1': 1742191452, 't2': 1742192174, 'd': 0, 'mrk': 0, 'c': ['KBA 887S(Siginon)(F)', '17.03.2025 06:04:12', {'t': 'Pamba Road, Mombasa, Kenya, 1.45 km from Changamwe', 'y': -4.01441860199, 'x': 39.6236686707, 'u': 17361689}, {'t': '17.03.2025 06:16:14', 'v': 1742192174, 'y': -4.01053333282, 'x': 39.6110496521, 'u': 17361689}, '0:12:02', '0:48:18', {'t': 'Magongo Road, Mombasa, Kenya, 1.40 km from Kwa Jomvu', 'y': -4.01053333282, 'x': 39.6110496521, 'u': 17361689}, '1:00:20', '3.47 km', {'t': '45 km/h', 'y': -4.01204204559, 'x': 39.6099128723, 'u': 17361689}, '20 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 63, 'i1': 14593, 'i2': 14624, 't1': 1741330442, 't2': 1741330820, 'd': 0, 'mrk': 0, 'c': ['KBA 891S(Siginon)(F)', '07.03.2025 06:54:02', {'t': 'Magongo Road, Mombasa, Kenya, Kwa Jomvu', 'y': -4.01821374893, 'x': 39.5927352905, 'u': 17790515}, {'t': '07.03.2025 07:00:20', 'v': 1741330820, 'y': -4.0158829689, 'x': 39.5912437439, 'u': 17790515}, '0:06:18', '0:16:00', {'t': 'Magongo Road, Mombasa, Kenya, Kwa Jomvu', 'y': -4.0158829689, 'x': 39.5912437439, 'u': 17790515}, '0:22:18', '0.53 km', {'t': '14 km/h', 'y': -4.01879167557, 'x': 39.5927276611, 'u': 17790515}, '6 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 149, 'i1': 41719, 'i2': 41759, 't1': 1742422576, 't2': 1742422988, 'd': 0, 'mrk': 0, 'c': ['KBA 891S(Siginon)(F)', '19.03.2025 22:16:16', {'t': 'Kipevu Road, Mombasa, Kenya, 1.23 km from Chaani', 'y': -4.04486179352, 'x': 39.6271591187, 'u': 17790515}, {'t': '19.03.2025 22:23:08', 'v': 1742422988, 'y': -4.06703901291, 'x': 39.6596221924, 'u': 17790515}, '0:06:52', '8:04:22', {'t': 'Taib Abdulla Nassir Road, Mombasa, Kenya, Liwatoni', 'y': -4.06703901291, 'x': 39.6596221924, 'u': 17790515}, '8:11:14', '1.13 km', {'t': '28 km/h', 'y': -4.06465339661, 'x': 39.6616439819, 'u': 17790515}, '46 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 3, 'i1': 2488, 'i2': 2553, 't1': 1740923030, 't2': 1740923734, 'd': 0, 'mrk': 0, 'c': ['KBA 892S(Siginon)(F)', '02.03.2025 13:43:50', {'t': 'Port Kilindini Road, Mombasa, Kenya, Liwatoni', 'y': -4.05825328827, 'x': 39.6503334045, 'u': 17367958}, {'t': '02.03.2025 13:55:34', 'v': 1740923734, 'y': -4.07005214691, 'x': 39.6643676758, 'u': 17367958}, '0:11:44', '0:05:00', {'t': 'Mbaraki Road, Mombasa, Kenya, Liwatoni', 'y': -4.07005214691, 'x': 39.6643676758, 'u': 17367958}, '0:16:44', '2.60 km', {'t': '31 km/h', 'y': -4.06053113937, 'x': 39.651889801, 'u': 17367958}, '14 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 125, 'i1': 195473, 'i2': 196047, 't1': 1742182083, 't2': 1742183667, 'd': 0, 'mrk': 0, 'c': ['KBS 539H(Siginon)(T)', '17.03.2025 03:28:03', {'t': 'Tororo - Magodes - Nabumali, Rubongi, Tororo, Eastern, Uganda', 'y': 0.7530983, 'x': 34.1782883, 'u': 17148300}, {'t': '17.03.2025 03:54:27', 'v': 1742183667, 'y': 0.7510366, 'x': 34.1805466, 'u': 17148300}, '0:26:24', '0:08:16', {'t': 'Tororo - Magodes - Nabumali, Rubongi, Tororo, Eastern, Uganda', 'y': 0.7510366, 'x': 34.1805466, 'u': 17148300}, '0:34:40', '2.54 km', {'t': '39 km/h', 'y': 0.7526966, 'x': 34.1776683, 'u': 17148300}, '6 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 3, 'i1': 608, 'i2': 635, 't1': 1740830678, 't2': 1740831030, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '01.03.2025 12:04:38', {'t': 'Kipevu Road, Mombasa, Kenya, Chaani', 'y': -4.03731012344, 'x': 39.6332778931, 'u': 17172446}, '01.03.2025 12:10:30', '0:05:52', '1:49:58', {'t': 'Port Kilindini Road, Mombasa, Kenya, 1.71 km from Makupa', 'y': -4.04091978073, 'x': 39.6422920227, 'u': 17172446}, '1:55:50', '1.24 km', {'t': '45 km/h', 'y': -4.04155921936, 'x': 39.6375427246, 'u': 17172446}, '17 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 4, 'i1': 800, 'i2': 815, 't1': 1740837628, 't2': 1740837756, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '01.03.2025 14:00:28', {'t': 'Port Kilindini Road, Mombasa, Kenya, 1.45 km from Liwatoni', 'y': -4.05780315399, 'x': 39.6490707397, 'u': 17172446}, {'t': '01.03.2025 14:02:36', 'v': 1740837756, 'y': -4.05644750595, 'x': 39.6490249634, 'u': 17172446}, '0:02:08', '1:25:34', {'t': 'Port Kilindini Road, Mombasa, Kenya, 1.56 km from Liwatoni', 'y': -4.05644750595, 'x': 39.6490249634, 'u': 17172446}, '1:27:42', '0.67 km', {'t': '23 km/h', 'y': -4.05701971054, 'x': 39.6499977112, 'u': 17172446}, '22 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 5, 'i1': 951, 'i2': 964, 't1': 1740842890, 't2': 1740843180, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '01.03.2025 15:28:10', {'t': 'Port Kilindini Road, Mombasa, Kenya, 1.47 km from Liwatoni', 'y': -4.056848526, 'x': 39.6498260498, 'u': 17172446}, {'t': '01.03.2025 15:33:00', 'v': 1740843180, 'y': -4.06956863403, 'x': 39.6652793884, 'u': 17172446}, '0:04:50', '0:39:30', {'t': 'Mbaraki Road, Mombasa, Kenya, Liwatoni', 'y': -4.06956863403, 'x': 39.6652793884, 'u': 17172446}, '0:44:20', '1.21 km', {'t': '30 km/h', 'y': -4.06254863739, 'x': 39.6581764221, 'u': 17172446}, '28 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 6, 'i1': 1028, 'i2': 1067, 't1': 1740845550, 't2': 1740846494, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', {'t': '01.03.2025 16:12:30', 'v': 1740845550, 'y': -4.06924772263, 'x': 39.6647109985, 'u': 17172446}, {'t': 'Mbaraki Road, Mombasa, Kenya, Liwatoni', 'y': -4.06924772263, 'x': 39.6647109985, 'u': 17172446}, '01.03.2025 16:28:14', '0:15:44', '0:10:52', {'t': 'Moi, Mombasa, Kenya, Liwatoni', 'y': -4.06123352051, 'x': 39.6550598145, 'u': 17172446}, '0:26:36', '2.20 km', {'t': '29 km/h', 'y': -4.06805562973, 'x': 39.6650886536, 'u': 17172446}, '8 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 8, 'i1': 1103, 'i2': 1259, 't1': 1740847538, 't2': 1740849120, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '01.03.2025 16:45:38', {'t': 'Moi, Mombasa, Kenya, Liwatoni', 'y': -4.06056070328, 'x': 39.6520271301, 'u': 17172446}, {'t': '01.03.2025 17:12:00', 'v': 1740849120, 'y': -4.04826450348, 'x': 39.6153755188, 'u': 17172446}, '0:26:22', '0:06:08', {'t': 'Port Reitz Road, Mombasa, Kenya, 1.93 km from Chaani', 'y': -4.04826450348, 'x': 39.6153755188, 'u': 17172446}, '0:32:30', '6.95 km', {'t': '41 km/h', 'y': -4.04846763611, 'x': 39.6468086243, 'u': 17172446}, '16 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 12, 'i1': 1460, 'i2': 1596, 't1': 1740854324, 't2': 1740855700, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '01.03.2025 18:38:44', {'t': 'Port Reitz Road, Mombasa, Kenya, 1.82 km from Chaani', 'y': -4.04586839676, 'x': 39.6140213013, 'u': 17172446}, {'t': '01.03.2025 19:01:40', 'v': 1740855700, 'y': -4.05855751038, 'x': 39.6488876343, 'u': 17172446}, '0:22:56', '3:16:50', {'t': 'Port Kilindini Road, Mombasa, Kenya, 1.41 km from Liwatoni', 'y': -4.05855751038, 'x': 39.6488876343, 'u': 17172446}, '3:39:46', '6.83 km', {'t': '54 km/h', 'y': -4.05698442459, 'x': 39.6494140625, 'u': 17172446}, '18 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 13, 'i1': 1870, 'i2': 1948, 't1': 1740867510, 't2': 1740868424, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '01.03.2025 22:18:30', {'t': 'Port Kilindini Road, Mombasa, Kenya, 1.41 km from Liwatoni', 'y': -4.05857944489, 'x': 39.6488723755, 'u': 17172446}, {'t': '01.03.2025 22:33:44', 'v': 1740868424, 'y': -4.06994628906, 'x': 39.664806366, 'u': 17172446}, '0:15:14', '0:11:46', {'t': 'Mbaraki Road, Mombasa, Kenya, Liwatoni', 'y': -4.06994628906, 'x': 39.664806366, 'u': 17172446}, '0:27:00', '2.92 km', {'t': '38 km/h', 'y': -4.06118345261, 'x': 39.6537704468, 'u': 17172446}, '12 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 14, 'i1': 1965, 'i2': 2000, 't1': 1740869130, 't2': 1740869666, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '01.03.2025 22:45:30', {'t': 'Mbaraki Road, Mombasa, Kenya, Liwatoni', 'y': -4.06996154785, 'x': 39.6643028259, 'u': 17172446}, {'t': '01.03.2025 22:54:26', 'v': 1740869666, 'y': -4.05822610855, 'x': 39.6560325623, 'u': 17172446}, '0:08:56', '0:09:18', {'t': 'Mozambique Road, Mombasa, Kenya, Liwatoni', 'y': -4.05822610855, 'x': 39.6560325623, 'u': 17172446}, '0:18:14', '1.95 km', {'t': '32 km/h', 'y': -4.06579065323, 'x': 39.6652946472, 'u': 17172446}, '14 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 19, 'i1': 3680, 'i2': 3714, 't1': 1740928352, 't2': 1740928570, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '02.03.2025 15:12:32', {'t': 'Port Kilindini Road, Mombasa, Kenya, 1.44 km from Liwatoni', 'y': -4.05787467957, 'x': 39.6491775513, 'u': 17172446}, {'t': '02.03.2025 15:16:10', 'v': 1740928570, 'y': -4.0584692955, 'x': 39.6504249573, 'u': 17172446}, '0:03:38', '0:17:32', {'t': 'Port Kilindini Road, Mombasa, Kenya, Liwatoni', 'y': -4.0584692955, 'x': 39.6504249573, 'u': 17172446}, '0:21:10', '0.71 km', {'t': '46 km/h', 'y': -4.0579161644, 'x': 39.6490325928, 'u': 17172446}, '12 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 20, 'i1': 3743, 'i2': 3796, 't1': 1740929622, 't2': 1740930040, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '02.03.2025 15:33:42', {'t': 'Port Kilindini Road, Mombasa, Kenya, Liwatoni', 'y': -4.0584692955, 'x': 39.6504249573, 'u': 17172446}, {'t': '02.03.2025 15:40:40', 'v': 1740930040, 'y': -4.06990003586, 'x': 39.6647911072, 'u': 17172446}, '0:06:58', '0:16:58', {'t': 'Mbaraki Road, Mombasa, Kenya, Liwatoni', 'y': -4.06990003586, 'x': 39.6647911072, 'u': 17172446}, '0:23:56', '1.86 km', {'t': '24 km/h', 'y': -4.06092834473, 'x': 39.6567230225, 'u': 17172446}, '22 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 21, 'i1': 3823, 'i2': 4031, 't1': 1740931058, 't2': 1740932926, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '02.03.2025 15:57:38', {'t': 'Mbaraki Road, Mombasa, Kenya, Liwatoni', 'y': -4.06990003586, 'x': 39.6647911072, 'u': 17172446}, {'t': '02.03.2025 16:28:46', 'v': 1740932926, 'y': -4.04732084274, 'x': 39.6134681702, 'u': 17172446}, '0:31:08', '0:44:36', {'t': 'Port Reitz Road, Mombasa, Kenya, 1.98 km from Chaani', 'y': -4.04732084274, 'x': 39.6134681702, 'u': 17172446}, '1:15:44', '10.13 km', {'t': '53 km/h', 'y': -4.06069421768, 'x': 39.6520080566, 'u': 17172446}, '20 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 23, 'i1': 4145, 'i2': 4276, 't1': 1740936208, 't2': 1740937456, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '02.03.2025 17:23:28', {'t': 'Port Reitz Road, Mombasa, Kenya, 1.60 km from Chaani', 'y': -4.0450387001, 'x': 39.6161613464, 'u': 17172446}, {'t': '02.03.2025 17:44:16', 'v': 1740937456, 'y': -4.05776405334, 'x': 39.6492500305, 'u': 17172446}, '0:20:48', '1:56:54', {'t': 'Port Kilindini Road, Mombasa, Kenya, 1.44 km from Liwatoni', 'y': -4.05776405334, 'x': 39.6492500305, 'u': 17172446}, '2:17:42', '7.06 km', {'t': '57 km/h', 'y': -4.05134439468, 'x': 39.6493453979, 'u': 17172446}, '21 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 24, 'i1': 4434, 'i2': 4505, 't1': 1740944470, 't2': 1740945296, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '02.03.2025 19:41:10', {'t': 'Port Kilindini Road, Mombasa, Kenya, 1.44 km from Liwatoni', 'y': -4.05776405334, 'x': 39.6492500305, 'u': 17172446}, {'t': '02.03.2025 19:54:56', 'v': 1740945296, 'y': -4.06990385056, 'x': 39.6646385193, 'u': 17172446}, '0:13:46', '0:12:20', {'t': 'Mbaraki Road, Mombasa, Kenya, Liwatoni', 'y': -4.06990385056, 'x': 39.6646385193, 'u': 17172446}, '0:26:06', '3.04 km', {'t': '35 km/h', 'y': -4.06077814102, 'x': 39.6521224976, 'u': 17172446}, '13 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 25, 'i1': 4526, 'i2': 4589, 't1': 1740946036, 't2': 1740946620, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '02.03.2025 20:07:16', {'t': 'Mbaraki Road, Mombasa, Kenya, Liwatoni', 'y': -4.06990385056, 'x': 39.6646385193, 'u': 17172446}, {'t': '02.03.2025 20:17:00', 'v': 1740946620, 'y': -4.05307626724, 'x': 39.6561584473, 'u': 17172446}, '0:09:44', '10:55:20', {'t': 'Mwangeka Road, Mombasa, Kenya, 1.25 km from Mombasa', 'y': -4.05307626724, 'x': 39.6561584473, 'u': 17172446}, '11:05:04', '2.80 km', {'t': '60 km/h', 'y': -4.06959581375, 'x': 39.665145874, 'u': 17172446}, '18 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 42, 'i1': 8669, 'i2': 8681, 't1': 1741080292, 't2': 1741080420, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '04.03.2025 09:24:52', {'t': 'Port Reitz Road, Mombasa, Kenya, 1.69 km from Chaani', 'y': -4.04606771469, 'x': 39.6160469055, 'u': 17172446}, {'t': '04.03.2025 09:27:00', 'v': 1741080420, 'y': -4.04603719711, 'x': 39.6161499023, 'u': 17172446}, '0:02:08', '2:04:12', {'t': 'Port Reitz Road, Mombasa, Kenya, 1.68 km from Chaani', 'y': -4.04603719711, 'x': 39.6161499023, 'u': 17172446}, '2:06:20', '0.21 km', {'t': '12 km/h', 'y': -4.04607534409, 'x': 39.6170158386, 'u': 17172446}, '7 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 45, 'i1': 9160, 'i2': 9177, 't1': 1741095402, 't2': 1741095816, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '04.03.2025 13:36:42', {'t': 'Kipevu Road, Mombasa, Kenya, Chaani', 'y': -4.04211950302, 'x': 39.6285438538, 'u': 17172446}, {'t': '04.03.2025 13:43:36', 'v': 1741095816, 'y': -4.04054260254, 'x': 39.6314468384, 'u': 17172446}, '0:06:54', '0:15:54', {'t': 'Kipevu Road, Mombasa, Kenya, Chaani', 'y': -4.04054260254, 'x': 39.6314468384, 'u': 17172446}, '0:22:48', '0.25 km', {'t': '14 km/h', 'y': -4.0418009758, 'x': 39.6297416687, 'u': 17172446}, '3 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 56, 'i1': 13778, 'i2': 13875, 't1': 1741271308, 't2': 1741272252, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', {'t': '06.03.2025 14:28:28', 'v': 1741271308, 'y': -4.05677270889, 'x': 39.6489486694, 'u': 17172446}, {'t': 'Port Kilindini Road, Mombasa, Kenya, 1.54 km from Liwatoni', 'y': -4.05677270889, 'x': 39.6489486694, 'u': 17172446}, '06.03.2025 14:44:12', '0:15:44', '0:05:00', {'t': 'Mbaraki Road, Mombasa, Kenya, Liwatoni', 'y': -4.06965875626, 'x': 39.6650238037, 'u': 17172446}, '0:20:44', '2.97 km', {'t': '25 km/h', 'y': -4.0620136261, 'x': 39.6581878662, 'u': 17172446}, '11 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 57, 'i1': 13881, 'i2': 13958, 't1': 1741272552, 't2': 1741273542, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '06.03.2025 14:49:12', {'t': 'Mbaraki Road, Mombasa, Kenya, Liwatoni', 'y': -4.06967544556, 'x': 39.664981842, 'u': 17172446}, '06.03.2025 15:05:42', '0:16:30', '0:07:54', {'t': 'Port Kilindini Road, Mombasa, Kenya, 1.77 km from Makupa', 'y': -4.04034423828, 'x': 39.6416358948, 'u': 17172446}, '0:24:24', '5.07 km', {'t': '57 km/h', 'y': -4.05441236496, 'x': 39.6496696472, 'u': 17172446}, '19 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 60, 'i1': 14289, 'i2': 14310, 't1': 1741282448, 't2': 1741282718, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', {'t': '06.03.2025 17:34:08', 'v': 1741282448, 'y': -4.04570102692, 'x': 39.61485672, 'u': 17172446}, {'t': 'Port Reitz Road, Mombasa, Kenya, 1.75 km from Chaani', 'y': -4.04570102692, 'x': 39.61485672, 'u': 17172446}, '06.03.2025 17:38:38', '0:04:30', '1:43:02', {'t': 'Port Reitz Road, Mombasa, Kenya, 1.81 km from Chaani', 'y': -4.04626607895, 'x': 39.6146087646, 'u': 17172446}, '1:47:32', '0.18 km', {'t': '14 km/h', 'y': -4.0454788208, 'x': 39.6149597168, 'u': 17172446}, '2 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 61, 'i1': 14490, 'i2': 14496, 't1': 1741288900, 't2': 1741288968, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '06.03.2025 19:21:40', {'t': 'Port Reitz Road, Mombasa, Kenya, 1.66 km from Chaani', 'y': -4.04522800446, 'x': 39.6154632568, 'u': 17172446}, {'t': '06.03.2025 19:22:48', 'v': 1741288968, 'y': -4.04511070251, 'x': 39.6162261963, 'u': 17172446}, '0:01:08', '0:36:06', {'t': 'Port Reitz Road, Mombasa, Kenya, 1.60 km from Chaani', 'y': -4.04511070251, 'x': 39.6162261963, 'u': 17172446}, '0:37:14', '0.06 km', {'t': '11 km/h', 'y': -4.0451631546, 'x': 39.6162109375, 'u': 17172446}, '12 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 63, 'i1': 14595, 'i2': 14608, 't1': 1741292646, 't2': 1741292778, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '06.03.2025 20:24:06', {'t': 'Kipevu Road, Mombasa, Kenya, 1.11 km from Chaani', 'y': -4.04387140274, 'x': 39.6251449585, 'u': 17172446}, {'t': '06.03.2025 20:26:18', 'v': 1741292778, 'y': -4.05855941772, 'x': 39.6491737366, 'u': 17172446}, '0:02:12', '3:39:26', {'t': 'Port Kilindini Road, Mombasa, Kenya, 1.39 km from Liwatoni', 'y': -4.05855941772, 'x': 39.6491737366, 'u': 17172446}, '3:41:38', '0.32 km', {'t': '30 km/h', 'y': -4.05840873718, 'x': 39.6495094299, 'u': 17172446}, '93 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 91, 'i1': 19583, 'i2': 19603, 't1': 1741434024, 't2': 1741434238, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', {'t': '08.03.2025 11:40:24', 'v': 1741434024, 'y': -4.04857063293, 'x': 39.6571083069, 'u': 17172446}, {'t': 'Sharif Abdul-Kadir Road, Mombasa, Kenya, 1.14 km from Mombasa', 'y': -4.04857063293, 'x': 39.6571083069, 'u': 17172446}, '08.03.2025 11:43:58', '0:03:34', '2:31:18', {'t': 'Miji Kenda Street, Mombasa, Kenya, Mombasa', 'y': -4.05604696274, 'x': 39.6585922241, 'u': 17172446}, '2:34:52', '0.99 km', {'t': '35 km/h', 'y': -4.05009126663, 'x': 39.6578865051, 'u': 17172446}, '17 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 92, 'i1': 19843, 'i2': 19846, 't1': 1741443316, 't2': 1741443424, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '08.03.2025 14:15:16', {'t': 'Moi, Mombasa, Kenya, Liwatoni', 'y': -4.0598783493, 'x': 39.6507797241, 'u': 17172446}, '08.03.2025 14:17:04', '0:01:48', '0:06:46', {'t': 'Port Reitz Road, Mombasa, Kenya, 1.56 km from Chaani', 'y': -4.04410648346, 'x': 39.6155471802, 'u': 17172446}, '0:08:34', '0.03 km', {'t': '16 km/h', 'y': -4.04410648346, 'x': 39.6155471802, 'u': 17172446}, '143 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 93, 'i1': 19873, 'i2': 19935, 't1': 1741443830, 't2': 1741444798, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '08.03.2025 14:23:50', {'t': 'Port Reitz Road, Mombasa, Kenya, 1.63 km from Chaani', 'y': -4.04499483109, 'x': 39.6156082153, 'u': 17172446}, {'t': '08.03.2025 14:39:58', 'v': 1741444798, 'y': -4.05673456192, 'x': 39.6497650146, 'u': 17172446}, '0:16:08', '17:51:08', {'t': 'Port Kilindini Road, Mombasa, Kenya, 1.49 km from Liwatoni', 'y': -4.05673456192, 'x': 39.6497650146, 'u': 17172446}, '18:07:16', '5.74 km', {'t': '45 km/h', 'y': -4.05342578888, 'x': 39.6492538452, 'u': 17172446}, '23 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 97, 'i1': 22223, 'i2': 22362, 't1': 1741534042, 't2': 1741535602, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '09.03.2025 15:27:22', {'t': 'Port Kilindini Road, Mombasa, Kenya, 1.46 km from Liwatoni', 'y': -4.05733776093, 'x': 39.6494750977, 'u': 17172446}, {'t': '09.03.2025 15:53:22', 'v': 1741535602, 'y': -4.04892539978, 'x': 39.6147575378, 'u': 17172446}, '0:26:00', '0:05:18', {'t': 'Port Reitz Road, Mombasa, Kenya, 2.03 km from Chaani', 'y': -4.04892539978, 'x': 39.6147575378, 'u': 17172446}, '0:31:18', '8.28 km', {'t': '52 km/h', 'y': -4.0458521843, 'x': 39.6206016541, 'u': 17172446}, '20 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 101, 'i1': 22739, 'i2': 22760, 't1': 1741545292, 't2': 1741545480, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '09.03.2025 18:34:52', {'t': 'Moi, Mombasa, Kenya, Liwatoni', 'y': -4.0587553978, 'x': 39.6502609253, 'u': 17172446}, {'t': '09.03.2025 18:38:00', 'v': 1741545480, 'y': -4.05778455734, 'x': 39.6500778198, 'u': 17172446}, '0:03:08', '0:17:44', {'t': 'Port Kilindini Road, Mombasa, Kenya, 1.38 km from Liwatoni', 'y': -4.05778455734, 'x': 39.6500778198, 'u': 17172446}, '0:20:52', '0.47 km', {'t': '20 km/h', 'y': -4.05990934372, 'x': 39.6511688232, 'u': 17172446}, '11 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 102, 'i1': 22793, 'i2': 22869, 't1': 1741546544, 't2': 1741547132, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '09.03.2025 18:55:44', {'t': 'Port Kilindini Road, Mombasa, Kenya, 1.38 km from Liwatoni', 'y': -4.05778169632, 'x': 39.6500549316, 'u': 17172446}, {'t': '09.03.2025 19:05:32', 'v': 1741547132, 'y': -4.07001113892, 'x': 39.6647758484, 'u': 17172446}, '0:09:48', '11:32:30', {'t': 'Mbaraki Road, Mombasa, Kenya, Liwatoni', 'y': -4.07001113892, 'x': 39.6647758484, 'u': 17172446}, '11:42:18', '2.52 km', {'t': '33 km/h', 'y': -4.06071233749, 'x': 39.6520385742, 'u': 17172446}, '17 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 105, 'i1': 24217, 'i2': 24266, 't1': 1741597434, 't2': 1741598156, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '10.03.2025 09:03:54', {'t': 'Port Reitz Road, Mombasa, Kenya, 1.81 km from Chaani', 'y': -4.04601240158, 'x': 39.6142921448, 'u': 17172446}, {'t': '10.03.2025 09:15:56', 'v': 1741598156, 'y': -4.04136991501, 'x': 39.630279541, 'u': 17172446}, '0:12:02', '2:52:52', {'t': 'Kipevu Road, Mombasa, Kenya, Chaani', 'y': -4.04136991501, 'x': 39.630279541, 'u': 17172446}, '3:04:54', '3.10 km', {'t': '46 km/h', 'y': -4.04181861877, 'x': 39.629776001, 'u': 17172446}, '16 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 115, 'i1': 28750, 'i2': 28760, 't1': 1741785932, 't2': 1741786156, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '12.03.2025 13:25:32', {'t': 'Magongo Road, Mombasa, Kenya, Kwa Jomvu', 'y': -4.00926685333, 'x': 39.5986289978, 'u': 17172446}, {'t': '12.03.2025 13:29:16', 'v': 1741786156, 'y': -4.00999212265, 'x': 39.6046257019, 'u': 17172446}, '0:03:44', '0:12:50', {'t': 'Magongo Road, Mombasa, Kenya, Kwa Jomvu', 'y': -4.00999212265, 'x': 39.6046257019, 'u': 17172446}, '0:16:34', '1.16 km', {'t': '36 km/h', 'y': -4.01026535034, 'x': 39.6070022583, 'u': 17172446}, '19 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 116, 'i1': 28782, 'i2': 28795, 't1': 1741786926, 't2': 1741787214, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '12.03.2025 13:42:06', {'t': 'Magongo Road, Mombasa, Kenya, Kwa Jomvu', 'y': -4.01000356674, 'x': 39.6046104431, 'u': 17172446}, {'t': '12.03.2025 13:46:54', 'v': 1741787214, 'y': -4.01064586639, 'x': 39.58934021, 'u': 17172446}, '0:04:48', '0:05:58', {'t': 'Magongo Road, Mombasa, Kenya, 1.35 km from Kwa Jomvu', 'y': -4.01064586639, 'x': 39.58934021, 'u': 17172446}, '0:10:46', '0.51 km', {'t': '17 km/h', 'y': -4.00934743881, 'x': 39.5937538147, 'u': 17172446}, '21 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 117, 'i1': 28803, 'i2': 28837, 't1': 1741787572, 't2': 1741788102, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '12.03.2025 13:52:52', {'t': 'Magongo Road, Mombasa, Kenya, 1.35 km from Kwa Jomvu', 'y': -4.01064109802, 'x': 39.5893440247, 'u': 17172446}, {'t': '12.03.2025 14:01:42', 'v': 1741788102, 'y': -4.01185750961, 'x': 39.584903717, 'u': 17172446}, '0:08:50', '1:55:06', {'t': 'Magongo Road, Mombasa, Kenya, 1.59 km from Miritini', 'y': -4.01185750961, 'x': 39.584903717, 'u': 17172446}, '2:03:56', '0.21 km', {'t': '12 km/h', 'y': -4.0110669136, 'x': 39.5853767395, 'u': 17172446}, '4 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 123, 'i1': 33514, 'i2': 33657, 't1': 1741974724, 't2': 1741976338, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '14.03.2025 17:52:04', {'t': 'Magongo Road, Mombasa, Kenya, 1.42 km from Miritini', 'y': -4.01205301285, 'x': 39.5830917358, 'u': 17172446}, {'t': '14.03.2025 18:18:58', 'v': 1741976338, 'y': -4.03668451309, 'x': 39.6158714294, 'u': 17172446}, '0:26:54', '0:26:28', {'t': 'Port Reitz Road, Mombasa, Kenya, 1.09 km from Chaani', 'y': -4.03668451309, 'x': 39.6158714294, 'u': 17172446}, '0:53:22', '14.07 km', {'t': '131 km/h', 'y': -4.00762414932, 'x': 39.574131012, 'u': 17172446}, '36 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 124, 'i1': 33704, 'i2': 33731, 't1': 1741977926, 't2': 1741978334, 'd': 0, 'mrk': 0, 'c': ['KBS 566H(Siginon)(F)', '14.03.2025 18:45:26', {'t': 'Port Reitz Road, Mombasa, Kenya, 1.09 km from Chaani', 'y': -4.03667879105, 'x': 39.6158790588, 'u': 17172446}, '14.03.2025 18:52:14', '0:06:48', '14:48:02', {'t': 'Refinery Road, Mombasa, Kenya, Changamwe', 'y': -4.02204942703, 'x': 39.6319847107, 'u': 17172446}, '14:54:50', '3.00 km', {'t': '90 km/h', 'y': -4.02390861511, 'x': 39.6320266724, 'u': 17172446}, '28 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 30, 'i1': 15326, 'i2': 15558, 't1': 1741338274, 't2': 1741343736, 'd': 0, 'mrk': 0, 'c': ['KCD 203Q(Siginon)(T)', {'t': '07.03.2025 09:04:34', 'v': 1741338274, 'y': -2.08064460754, 'x': 37.4756240845, 'u': 26116323}, {'t': 'Mombasa Road, Emali, Makueni, Kenya', 'y': -2.08064460754, 'x': 37.4756240845, 'u': 26116323}, '07.03.2025 10:35:36', '1:31:02', '0:06:30', {'t': 'Mombasa Road, Makueni, Kenya, 7.30 km from Mapepie', 'y': -1.79271864891, 'x': 37.2183532715, 'u': 26116323}, '1:37:32', '45.71 km', {'t': '66 km/h', 'y': -1.80782783031, 'x': 37.2224349976, 'u': 26116323}, '30 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 103, 'i1': 41013, 'i2': 41018, 't1': 1742118486, 't2': 1742118578, 'd': 0, 'mrk': 0, 'c': ['KCD 203Q(Siginon)(T)', {'t': '16.03.2025 09:48:06', 'v': 1742118486, 'y': 0.753344833851, 'x': 34.1782417297, 'u': 26116323}, {'t': 'Tororo - Magodes - Nabumali, Rubongi, Tororo, Eastern, Uganda', 'y': 0.753344833851, 'x': 34.1782417297, 'u': 26116323}, '16.03.2025 09:49:38', '0:01:32', '0:35:02', {'t': 'Mbale - Tororo Road, Uganda, 2.51 km from Mukuju', 'y': 0.757495820522, 'x': 34.1837501526, 'u': 26116323}, '0:36:34', '0.79 km', {'t': '28 km/h', 'y': 0.757495820522, 'x': 34.1837501526, 'u': 26116323}, '31 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 11, 'i1': 13847, 'i2': 13866, 't1': 1741099696, 't2': 1741099858, 'd': 0, 'mrk': 0, 'c': ['KCG 302H(Siginon)(TR)', {'t': '04.03.2025 14:48:16', 'v': 1741099696, 'y': 0.464309990406, 'x': 34.1025123596, 'u': 18723370}, {'t': 'Kisumu-Busia Road, Busia, Kenya', 'y': 0.464309990406, 'x': 34.1025123596, 'u': 18723370}, {'t': '04.03.2025 14:50:58', 'v': 1741099858, 'y': 0.464635491371, 'x': 34.1015853882, 'u': 18723370}, '0:02:42', '0:39:04', {'t': 'Kisumu-Busia Road, Busia, Kenya', 'y': 0.464635491371, 'x': 34.1015853882, 'u': 18723370}, '0:41:46', '0.11 km', '0 km/h', '2 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 21, 'i1': 33989, 'i2': 34094, 't1': 1741184168, 't2': 1741184676, 'd': 0, 'mrk': 0, 'c': ['KCG 302H(Siginon)(TR)', {'t': '05.03.2025 14:16:08', 'v': 1741184168, 'y': 0.465564996004, 'x': 34.0966110229, 'u': 18723370}, {'t': 'Customs Street, Eastern Division, Busia, Eastern, Uganda', 'y': 0.465564996004, 'x': 34.0966110229, 'u': 18723370}, {'t': '05.03.2025 14:24:36', 'v': 1741184676, 'y': 0.465551674366, 'x': 34.0977630615, 'u': 18723370}, '0:08:28', '0:23:28', {'t': 'Customs Street, Eastern Division, Busia, Eastern, Uganda', 'y': 0.465551674366, 'x': 34.0977630615, 'u': 18723370}, '0:31:56', '1.13 km', '0 km/h', '8 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 141, 'i1': 53054, 'i2': 53092, 't1': 1742392666, 't2': 1742393218, 'd': 0, 'mrk': 0, 'c': ['KCQ 736J(Siginon)(T)', {'t': '19.03.2025 13:57:46', 'v': 1742392666, 'y': -4.04659891129, 'x': 39.6467666626, 'u': 17793189}, {'t': 'Port Kilindini Road, Mombasa, Kenya, 1.50 km from Makupa', 'y': -4.04659891129, 'x': 39.6467666626, 'u': 17793189}, '19.03.2025 14:06:58', '0:09:12', '0:11:12', {'t': 'Port Kilindini Road, Mombasa, Kenya, 1.75 km from Makupa', 'y': -4.04399728775, 'x': 39.6427574158, 'u': 17793189}, '0:20:24', '1.38 km', {'t': '28 km/h', 'y': -4.04759979248, 'x': 39.6449279785, 'u': 17793189}, '9 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 142, 'i1': 53112, 'i2': 53202, 't1': 1742393890, 't2': 1742394742, 'd': 0, 'mrk': 0, 'c': ['KCQ 736J(Siginon)(T)', '19.03.2025 14:18:10', {'t': 'Port Kilindini Road, Mombasa, Kenya, 1.75 km from Makupa', 'y': -4.04399728775, 'x': 39.6427574158, 'u': 17793189}, {'t': '19.03.2025 14:32:22', 'v': 1742394742, 'y': -4.05315685272, 'x': 39.6562232971, 'u': 17793189}, '0:14:12', '1 days 0:11:52', {'t': 'Mwangeka Road, Mombasa, Kenya, 1.25 km from Mombasa', 'y': -4.05315685272, 'x': 39.6562232971, 'u': 17793189}, '1 days 0:26:04', '3.05 km', {'t': '40 km/h', 'y': -4.06117725372, 'x': 39.653503418, 'u': 17793189}, '21 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 97, 'i1': 119360, 'i2': 119390, 't1': 1742410714, 't2': 1742411134, 'd': 0, 'mrk': 0, 'c': ['KCT 742S(Siginon)(T)', {'t': '19.03.2025 18:58:34', 'v': 1742410714, 'y': 0.64349681139, 'x': 34.2439994812, 'u': 19034625}, {'t': 'Kenya Road, Malaba Town Council, Tororo, Eastern, Uganda', 'y': 0.64349681139, 'x': 34.2439994812, 'u': 19034625}, {'t': '19.03.2025 19:05:34', 'v': 1742411134, 'y': 0.6449213624, 'x': 34.2398490906, 'u': 19034625}, '0:07:00', '0:08:26', {'t': 'Kenya Road, Malaba Town Council, Tororo, Eastern, Uganda', 'y': 0.6449213624, 'x': 34.2398490906, 'u': 19034625}, '0:15:26', '0.49 km', '0 km/h', '4 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 42, 'i1': 13240, 'i2': 13244, 't1': 1741269388, 't2': 1741269508, 'd': 0, 'mrk': 0, 'c': ['KDB 435A(Siginon)(T)', {'t': '06.03.2025 13:56:28', 'v': 1741269388, 'y': -3.84659957886, 'x': 39.4519500732, 'u': 22446570}, {'t': 'Mombasa Road, Kilifi, Kenya, 3.22 km from Mariakani', 'y': -3.84659957886, 'x': 39.4519500732, 'u': 22446570}, {'t': '06.03.2025 13:58:28', 'v': 1741269508, 'y': -3.8453373909, 'x': 39.4507446289, 'u': 22446570}, '0:02:00', '0:24:00', {'t': 'Mombasa Road, Kilifi, Kenya, 3.42 km from Mariakani', 'y': -3.8453373909, 'x': 39.4507446289, 'u': 22446570}, '0:26:00', '0.19 km', '0 km/h', '6 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 92, 'i1': 25841, 'i2': 26364, 't1': 1741663412, 't2': 1741673418, 'd': 0, 'mrk': 0, 'c': ['KDB 940U(Siginon)(T)', {'t': '11.03.2025 03:23:32', 'v': 1741663412, 'y': -1.42995083332, 'x': 36.9571990967, 'u': 17147144}, {'t': 'Nairobi-Namanga-Athi River Road, Machakos, Kenya, 19.19 km from Nairobi', 'y': -1.42995083332, 'x': 36.9571990967, 'u': 17147144}, '11.03.2025 06:10:18', '2:46:46', '0:06:00', {'t': 'Mombasa Road, Makueni, Kenya, Kiboko', 'y': -2.21126890182, 'x': 37.7214126587, 'u': 17147144}, '2:52:46', '132.32 km', {'t': '77 km/h', 'y': -1.57841205597, 'x': 37.1560096741, 'u': 17147144}, '48 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 121, 'i1': 37131, 'i2': 37156, 't1': 1741965120, 't2': 1741965778, 'd': 0, 'mrk': 0, 'c': ['KDC 683X(Siginon)(T)', '14.03.2025 15:12:00', {'t': 'Zanzibar Road, Mombasa, Kenya, 1.23 km from Liwatoni', 'y': -4.05686759949, 'x': 39.6538085938, 'u': 24276083}, {'t': '14.03.2025 15:22:58', 'v': 1741965778, 'y': -4.0475230217, 'x': 39.6501312256, 'u': 24276083}, '0:10:58', '0:54:00', {'t': 'Shimanzi Road, Mombasa, Kenya, 1.31 km from Makupa', 'y': -4.0475230217, 'x': 39.6501312256, 'u': 24276083}, '1:04:58', '1.13 km', {'t': '24 km/h', 'y': -4.05208444595, 'x': 39.6507072449, 'u': 24276083}, '7 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 5, 'i1': 3373, 'i2': 3768, 't1': 1740921140, 't2': 1740927980, 'd': 0, 'mrk': 0, 'c': ['KDG 882A(Siginon)(T)', '02.03.2025 13:12:20', {'t': 'Mombasa Road, Kwale, Kenya, 2.12 km from Samburu', 'y': -3.79249572754, 'x': 39.2600631714, 'u': 24766263}, {'t': '02.03.2025 15:06:20', 'v': 1740927980, 'y': -4.05293655396, 'x': 39.6563835144, 'u': 24766263}, '1:54:00', '14:44:42', {'t': 'Mwangeka Road, Mombasa, Kenya, 1.23 km from Mombasa', 'y': -4.05293655396, 'x': 39.6563835144, 'u': 24766263}, '16:38:42', '61.72 km', {'t': '74 km/h', 'y': -3.78859448433, 'x': 39.3754768372, 'u': 24766263}, '32 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 106, 'i1': 50009, 'i2': 50011, 't1': 1742379900, 't2': 1742380020, 'd': 0, 'mrk': 0, 'c': ['KDH 758P(Siginon)(T)', {'t': '19.03.2025 10:25:00', 'v': 1742379900, 'y': -0.142746672034, 'x': 35.6817550659, 'u': 25570815}, {'t': 'Nakuru - Eldoret Road, Nakuru, Kenya, 4.17 km from Koige', 'y': -0.142746672034, 'x': 35.6817550659, 'u': 25570815}, {'t': '19.03.2025 10:27:00', 'v': 1742380020, 'y': -0.142381995916, 'x': 35.6809043884, 'u': 25570815}, '0:02:00', '0:08:24', {'t': 'Nakuru - Eldoret Road, Nakuru, Kenya, 4.27 km from Koige', 'y': -0.142381995916, 'x': 35.6809043884, 'u': 25570815}, '0:10:24', '0.10 km', '0 km/h', '3 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 148, 'i1': 26377, 'i2': 26402, 't1': 1742394467, 't2': 1742394685, 'd': 0, 'mrk': 0, 'c': ['KDK 940W(Siginon)(T)', '19.03.2025 14:27:47', {'t': 'Kenya Road, Malaba Town Council, Tororo, Eastern, Uganda', 'y': 0.6388133, 'x': 34.2643583, 'u': 26411880}, {'t': '19.03.2025 14:31:25', 'v': 1742394685, 'y': 0.6397616, 'x': 34.2601899, 'u': 26411880}, '0:03:38', '1:24:54', {'t': 'Kenya Road, Malaba Town Council, Tororo, Eastern, Uganda', 'y': 0.6397616, 'x': 34.2601899, 'u': 26411880}, '1:28:32', '0.37 km', {'t': '14 km/h', 'y': 0.6397183, 'x': 34.2609433, 'u': 26411880}, '8 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 149, 'i1': 26453, 'i2': 26456, 't1': 1742399779, 't2': 1742400115, 'd': 0, 'mrk': 0, 'c': ['KDK 940W(Siginon)(T)', '19.03.2025 15:56:19', {'t': 'Kenya Road, Malaba Town Council, Tororo, Eastern, Uganda', 'y': 0.6397616, 'x': 34.2601899, 'u': 26411880}, '19.03.2025 16:01:55', '0:05:36', '0:07:18', {'t': 'Kenya Road, Eastern Division, Tororo, Eastern, Uganda', 'y': 0.6627983, 'x': 34.1970616, 'u': 26411880}, '0:12:54', '0.00 km', {'t': '36 km/h', 'y': 0.6627983, 'x': 34.1970616, 'u': 26411880}, '80 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 150, 'i1': 26463, 'i2': 26469, 't1': 1742400553, 't2': 1742400870, 'd': 0, 'mrk': 0, 'c': ['KDK 940W(Siginon)(T)', '19.03.2025 16:09:13', {'t': 'Kenya Road, Eastern Division, Tororo, Eastern, Uganda', 'y': 0.6627983, 'x': 34.1970616, 'u': 26411880}, '19.03.2025 16:14:30', '0:05:17', '0:06:15', {'t': 'Busia Road, Eastern Division, Tororo, Eastern, Uganda', 'y': 0.6798716, 'x': 34.1777383, 'u': 26411880}, '0:11:32', '0.19 km', {'t': '22 km/h', 'y': 0.6792316, 'x': 34.1775516, 'u': 26411880}, '33 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 151, 'i1': 26474, 'i2': 26487, 't1': 1742401245, 't2': 1742401509, 'd': 0, 'mrk': 0, 'c': ['KDK 940W(Siginon)(T)', '19.03.2025 16:20:45', {'t': 'Busia Road, Eastern Division, Tororo, Eastern, Uganda', 'y': 0.6798716, 'x': 34.1777383, 'u': 26411880}, {'t': '19.03.2025 16:25:09', 'v': 1742401509, 'y': 0.72574, 'x': 34.1855333, 'u': 26411880}, '0:04:24', '14:31:58', {'t': 'Tororo - Magodes - Nabumali, Rubongi, Tororo, Eastern, Uganda', 'y': 0.72574, 'x': 34.1855333, 'u': 26411880}, '14:36:22', '1.70 km', {'t': '47 km/h', 'y': 0.7136566, 'x': 34.1846583, 'u': 26411880}, '71 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 155, 'i1': 27155, 'i2': 27546, 't1': 1742465195, 't2': 1742470836, 'd': 0, 'mrk': 0, 'c': ['KDK 940W(Siginon)(T)', {'t': '20.03.2025 10:06:35', 'v': 1742465195, 'y': 0.793865, 'x': 34.3791366, 'u': 26411880}, {'t': 'Lwakaka, Uganda', 'y': 0.793865, 'x': 34.3791366, 'u': 26411880}, '20.03.2025 11:40:36', '1:34:01', '0:16:17', {'t': 'Eldoret Road, Bungoma, Kenya, 2.74 km from Bungoma', 'y': 0.5928333, 'x': 34.5495133, 'u': 26411880}, '1:50:18', '49.48 km', {'t': '71 km/h', 'y': 0.71014, 'x': 34.568165, 'u': 26411880}, '32 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 156, 'i1': 27554, 'i2': 27564, 't1': 1742471813, 't2': 1742472096, 'd': 0, 'mrk': 0, 'c': ['KDK 940W(Siginon)(T)', {'t': '20.03.2025 11:56:53', 'v': 1742471813, 'y': 0.610225, 'x': 34.6505083, 'u': 26411880}, {'t': 'Eldoret-Malaba Road, Bungoma, Kenya, 2.16 km from Sudi', 'y': 0.610225, 'x': 34.6505083, 'u': 26411880}, '20.03.2025 12:01:36', '0:04:43', '0:33:44', {'t': 'Eldoret-Malaba Road, Bungoma, Kenya, 2.25 km from Sudi', 'y': 0.6115633, 'x': 34.6543633, 'u': 26411880}, '0:38:27', '0.54 km', {'t': '31 km/h', 'y': 0.610225, 'x': 34.6505083, 'u': 26411880}, '7 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 157, 'i1': 27580, 'i2': 27644, 't1': 1742474120, 't2': 1742475994, 'd': 0, 'mrk': 0, 'c': ['KDK 940W(Siginon)(T)', {'t': '20.03.2025 12:35:20', 'v': 1742474120, 'y': 0.6066049, 'x': 34.7626566, 'u': 26411880}, {'t': 'Eldoret-Malaba Road, Webuye, Bungoma, Kenya', 'y': 0.6066049, 'x': 34.7626566, 'u': 26411880}, '20.03.2025 13:06:34', '0:31:14', '0:09:46', {'t': 'Eldoret-Malaba Road, Kakamega, Kenya, 6.82 km from Himoi', 'y': 0.6052316, 'x': 34.8810933, 'u': 26411880}, '0:41:00', '15.70 km', {'t': '64 km/h', 'y': 0.5905366, 'x': 34.77348, 'u': 26411880}, '30 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 158, 'i1': 27652, 'i2': 27664, 't1': 1742476580, 't2': 1742476836, 'd': 0, 'mrk': 0, 'c': ['KDK 940W(Siginon)(T)', '20.03.2025 13:16:20', {'t': 'Eldoret-Malaba Road, Kakamega, Kenya, 6.82 km from Himoi', 'y': 0.6052316, 'x': 34.8810933, 'u': 26411880}, {'t': '20.03.2025 13:20:36', 'v': 1742476836, 'y': 0.6092116, 'x': 34.9681516, 'u': 26411880}, '0:04:16', '0:05:00', {'t': 'Turbo-Jua Kali Road, Uasin Gishu, Kenya, Kipkarren', 'y': 0.6092116, 'x': 34.9681516, 'u': 26411880}, '0:09:16', '1.79 km', {'t': '51 km/h', 'y': 0.6081683, 'x': 34.959345, 'u': 26411880}, '137 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 159, 'i1': 27666, 'i2': 27753, 't1': 1742477136, 't2': 1742478635, 'd': 0, 'mrk': 0, 'c': ['KDK 940W(Siginon)(T)', '20.03.2025 13:25:36', {'t': 'Turbo-Jua Kali Road, Uasin Gishu, Kenya, Kipkarren', 'y': 0.6092116, 'x': 34.9681516, 'u': 26411880}, '20.03.2025 13:50:35', '0:24:59', '0:09:07', {'t': 'Turbo - Jua Kali Road, Uasin Gishu, Kenya, 4.00 km from Leseru', 'y': 0.61402, 'x': 35.120205, 'u': 26411880}, '0:34:06', '12.99 km', {'t': '86 km/h', 'y': 0.6151333, 'x': 35.1113216, 'u': 26411880}, '43 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 160, 'i1': 27756, 'i2': 27800, 't1': 1742479182, 't2': 1742479843, 'd': 0, 'mrk': 0, 'c': ['KDK 940W(Siginon)(T)', {'t': '20.03.2025 13:59:42', 'v': 1742479182, 'y': 0.6140383, 'x': 35.1202933, 'u': 26411880}, {'t': 'Turbo - Jua Kali Road, Uasin Gishu, Kenya, 3.99 km from Leseru', 'y': 0.6140383, 'x': 35.1202933, 'u': 26411880}, '20.03.2025 14:10:43', '0:11:01', '0:21:52', {'t': 'Turbo - Jua Kali Road, Uasin Gishu, Kenya, 1.39 km from Leseru', 'y': 0.6017016, 'x': 35.1658483, 'u': 26411880}, '0:32:53', '5.45 km', {'t': '83 km/h', 'y': 0.6009133, 'x': 35.1534316, 'u': 26411880}, '30 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 161, 'i1': 27809, 'i2': 28634, 't1': 1742481155, 't2': 1742494759, 'd': 0, 'mrk': 0, 'c': ['KDK 940W(Siginon)(T)', '20.03.2025 14:32:35', {'t': 'Turbo - Jua Kali Road, Uasin Gishu, Kenya, 1.56 km from Leseru', 'y': 0.6018533, 'x': 35.16731, 'u': 26411880}, {'t': '20.03.2025 18:19:19', 'v': 1742494759, 'y': -0.2070766, 'x': 35.8508133, 'u': 26411880}, '3:46:44', '9:02:45', {'t': 'Nakuru - Eldoret Road, Nakuru, Kenya, Tegat', 'y': -0.2070766, 'x': 35.8508133, 'u': 26411880}, '12:49:29', '147.96 km', {'t': '104 km/h', 'y': -0.0415366, 'x': 35.6354183, 'u': 26411880}, '39 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 32, 'i1': 50457, 'i2': 50714, 't1': 1741436465, 't2': 1741437427, 'd': 0, 'mrk': 0, 'c': ['KDM 503E(Siginon)(B)', {'t': '08.03.2025 12:21:05', 'v': 1741436465, 'y': 0.6046183, 'x': 34.7636733, 'u': 27046048}, {'t': 'Eldoret-Malaba Road, Webuye, Bungoma, Kenya', 'y': 0.6046183, 'x': 34.7636733, 'u': 27046048}, '08.03.2025 12:37:07', '0:16:02', '0:06:31', {'t': 'Eldoret-Malaba Road, Webuye, Bungoma, Kenya', 'y': 0.6078633, 'x': 34.7611966, 'u': 27046048}, '0:22:33', '0.65 km', {'t': '11 km/h', 'y': 0.6080983, 'x': 34.7613316, 'u': 27046048}, '2 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 33, 'i1': 50742, 'i2': 52517, 't1': 1741437818, 't2': 1741443314, 'd': 0, 'mrk': 0, 'c': ['KDM 503E(Siginon)(B)', '08.03.2025 12:43:38', {'t': 'Eldoret-Malaba Road, Webuye, Bungoma, Kenya', 'y': 0.6078233, 'x': 34.7610983, 'u': 27046048}, {'t': '08.03.2025 14:15:14', 'v': 1741443314, 'y': 0.60975, 'x': 34.3551066, 'u': 27046048}, '1:31:36', '0:09:45', {'t': 'Eldoret Road, Busia, Kenya, 1.64 km from Kocholya', 'y': 0.60975, 'x': 34.3551066, 'u': 27046048}, '1:41:21', '47.30 km', {'t': '68 km/h', 'y': 0.5922516, 'x': 34.5181666, 'u': 27046048}, '31 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 76, 'i1': 14126, 'i2': 14667, 't1': 1741614426, 't2': 1741626405, 'd': 0, 'mrk': 0, 'c': ['KDM 516E(Siginon)(T)', {'t': '10.03.2025 13:47:06', 'v': 1741614426, 'y': -3.5620683, 'x': 38.756015, 'u': 27076055}, {'t': 'Mombasa Road, Taita Taveta, Kenya, Maungu', 'y': -3.5620683, 'x': 38.756015, 'u': 27076055}, '10.03.2025 17:06:45', '3:19:39', '0:39:48', {'t': 'Port Reitz Road, Mombasa, Kenya, 2.44 km from Chaani', 'y': -4.0417683, 'x': 39.6047316, 'u': 27076055}, '3:59:27', '120.78 km', {'t': '73 km/h', 'y': -3.6997366, 'x': 38.9919416, 'u': 27076055}, '36 km/h', '']}: string indices must be integers, not 'str'
# Error processing sub-item {'n': 77, 'i1': 14681, 'i2': 14777, 't1': 1741628793, 't2': 1741629737, 'd': 0, 'mrk': 0, 'c': ['KDM 516E(Siginon)(T)', '10.03.2025 17:46:33', {'t': 'Port Reitz Road, Mombasa, Kenya, 2.42 km from Chaani', 'y': -4.042035, 'x': 39.60507, 'u': 27076055}, {'t': '10.03.2025 18:02:17', 'v': 1741629737, 'y': -4.043375, 'x': 39.6099, 'u': 27076055}, '0:15:44', '0:17:34', {'t': 'Port Reitz Road, Mombasa, Kenya, 2.00 km from Chaani', 'y': -4.043375, 'x': 39.6099, 'u': 27076055}, '0:33:18', '3.29 km', {'t': '29 km/h', 'y': -4.0434266, 'x': 39.6078516, 'u': 27076055}, '13 km/h', '']}: string indices must be integers, not 'str'
# Sub-rows data successfully exported and ready for download!
#       Truck No   Departure DateTime  \
# 0      KBA876S  03/01/2025 12:00:08
# 1      KBA876S  03/01/2025 14:49:08
# 2      KBA876S  03/01/2025 15:02:18
# 3      KBA876S  03/01/2025 15:33:36
# 4      KBA876S  03/01/2025 15:54:39
# ...        ...                  ...
# 25080  KDM523E  03/22/2025 09:12:38
# 25081  KDM523E  03/22/2025 10:02:18
# 25082  KDM523E  03/22/2025 10:18:56
# 25083  KDM523E  03/22/2025 10:28:34
# 25084  KDM523E  03/22/2025 10:42:00
#
#                                           Departure From     Arrival DateTime  \
# 0       Kipevu Road, Mombasa, Kenya, 1.31 km from Chaani  03/01/2025 12:14:08
# 1      Port Kilindini Road, Mombasa, Kenya, 1.44 km f...  03/01/2025 14:52:18
# 2                          Moi, Mombasa, Kenya, Liwatoni  03/01/2025 15:17:30
# 3                 Mbaraki Road, Mombasa, Kenya, Liwatoni  03/01/2025 15:49:39
# 4                          Moi, Mombasa, Kenya, Liwatoni  03/01/2025 16:07:49
# ...                                                  ...                  ...
# 25080  Mwangeka Road, Mombasa, Kenya, 1.22 km from Mo...  03/22/2025 09:23:56
# 25081                      Moi, Mombasa, Kenya, Liwatoni  03/22/2025 10:12:56
# 25082   Kipevu Road, Mombasa, Kenya, 1.11 km from Chaani  03/22/2025 10:23:34
# 25083   Kipevu Road, Mombasa, Kenya, 1.20 km from Chaani  03/22/2025 10:34:44
# 25084                Kipevu Road, Mombasa, Kenya, Chaani  03/22/2025 10:50:54
#
#          Driving Time   Standing Time  Idle Time  \
# 0     0 days 00:14:00 0 days 02:35:00   2.583333
# 1     0 days 00:03:10 0 days 00:10:00   0.166667
# 2     0 days 00:15:12 0 days 00:16:06   0.268333
# 3     0 days 00:16:03 0 days 00:05:00   0.083333
# 4     0 days 00:13:10 0 days 00:45:00   0.750000
# ...               ...             ...        ...
# 25080 0 days 00:11:18 0 days 00:38:22   0.639444
# 25081 0 days 00:10:38 0 days 00:06:00   0.100000
# 25082 0 days 00:04:38 0 days 00:05:00   0.083333
# 25083 0 days 00:06:10 0 days 00:07:16   0.121111
# 25084 0 days 00:08:54 0 days 00:00:00   0.000000
#
#                                               Arrived at  Distance  \
# 0      Port Kilindini Road, Mombasa, Kenya, 1.46 km f...      5.10
# 1          Port Kilindini Road, Mombasa, Kenya, Liwatoni      0.44
# 2                 Mbaraki Road, Mombasa, Kenya, Liwatoni      2.74
# 3                          Moi, Mombasa, Kenya, Liwatoni      2.69
# 4       Kipevu Road, Mombasa, Kenya, 1.07 km from Chaani      4.12
# ...                                                  ...       ...
# 25080                      Moi, Mombasa, Kenya, Liwatoni      4.05
# 25081   Kipevu Road, Mombasa, Kenya, 1.11 km from Chaani      4.31
# 25082   Kipevu Road, Mombasa, Kenya, 1.20 km from Chaani      0.43
# 25083                Kipevu Road, Mombasa, Kenya, Chaani      0.93
# 25084  Port Kilindini Road, Mombasa, Kenya, 1.68 km f...      2.68
#
#       Maximum Speed Average Speed Driver
# 0           36 km/h       22 km/h
# 1           16 km/h        8 km/h
# 2           27 km/h       11 km/h
# 3           31 km/h       10 km/h
# 4           45 km/h       19 km/h
# ...             ...           ...    ...
# 25080       39 km/h       21 km/h
# 25081       53 km/h       24 km/h
# 25082       22 km/h        6 km/h
# 25083       28 km/h        9 km/h
# 25084       45 km/h       18 km/h
#
# [25085 rows x 12 columns]
